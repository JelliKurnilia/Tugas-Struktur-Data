# %% [markdown]
# # **EXERCISE 11 MATA KULIAH STRUKTUR DATA**
# # **LINEAR DATA STUCTURE**
# ## **Jelli Kurnilia/121450083/RC**

# %% [markdown]
# # Latihan Bab Linear Data Structure

# %% [markdown]
# ## 1. Stacks, Queues , Deques
# a) Jelaskan pengertian Stack, Queues dan Deques dalam struktur data
#
# b) Jelaskan perbedaan antara Stack, Queues dan Deques
#
#     JAWAB :
# a)
#
# *   Stack adalah perintah pengumpulan data secara linear yang menyusun dataItem daftar seperti tumpukan dan bersifat **LIFO** (Last In First Out), yang berarti data yang terakhir masuk adalah data yang pertama keluar.
#
# contoh : Setumpuk buku berisi tugas-tugas kuliah berada di atas meja Dosen, dimana buku tugas yang paling terakhir ditambahkan dan ditaruh diatas adalah buku tugas yang dapat dilihat dan dinilai dahulu 😀
#
# Pada Stack terdapat beberapa fungsi operasi diantaranya yaitu :
#
#     - Push untuk memasukkan atau menginputkan data
#     - Pop  untuk mengeluarkan data
#     - IsFull untuk mengetahui jika tumpikan sudah penuh
#     - IsEmpety untuk mengetahui tumpukan yang kosong, dan
#     - Clear untuk menghapus seluruh data atau membersihkan data
#
#
#
# * Queues adalah sekumpulan data yang mana penambahan elemen hanya bisa dilakukan pada suatu ujung disebut dengan sisibelakang(rear), dan penghapusan(pengambilan elemen) dilakukan lewat ujung lain (disebut dengan sisi depan atau front).Queues bersifat **FIFO** (First In First Out) yang artinya, data yang pertama kali masuk merupakan data yang akan keluar paing awal.
#
# Contoh : Antrian untuk membeli pertamax di SPBU
#
# Pada Queue terdapat beberapa fungsi operasi diantaranya yaitu :
#
#     - EnQueue untuk Memasukkan data kedalam Antrian
#     - DeQueue untuk Mengeluarkan data kedalam Antrian.
#     - IsFull untuk memeriksa apakah antrian Penuh
#     - IsEmpety untuk memeriksa apakah antrian Kosong
#     - Clear untuk Menghapus seluruh Antrian
#
#
#   * Deques adalah antrian dimana elemennya bisa masuk dan keluar lewat kedua ujungnya dan disajikan dengan menggunakan Double link list.

# %% [markdown]
# # 2. Linked Lists
# a) Jelaskan pengertian Linked Lists dalam struktur data
#
# b) Jelaskan perbedaan antara Single Linked List dengan Double Linked List
#
# c) Carilah deskripsi dan jelaskan contoh penerapan lain pada Linked List yaitu Circular Linked sist
#
# d) Jelaskan perbedaan antara Single Linked List, Double Linked List dan Circular Linked List
#
#
#
#     JAWAB :
# a) **Linked List** adalah struktur data yang terdiri dari urutan record data dimana setiap record memiliki field yang menyimpan alamat/referensi dari record selanjutnya (dalam urutan). Elemen data yang dihubungkan dengan link pada Linked List disebut Node. Setiap node mempertahankan referensi ke elemennya
# dan satu atau lebih referensi ke tetangga node untuk secara kolektif mewakili
# urutan linear dari urutan.
# Ada beberapa macam Linked List, yaitu :
# Single Linked List, Double Linked List, Circular Linked List dan Multiple Linked List.
#
# b) Perbedaan mendasar antara Single Linked List dengan Double Linked List adalah Single Linked List hanya memiliki 1 pointer yang berfungsi untuk menunjuk Node selanjutnya. Sedangkan Double Linked List memiliki 2 pointer. dapa Single Linked List **hanya bisa** menghapus data dari depan ke belakang, sedangkan Double Linked List dapat menghapus data dari depan, belakang, kanan ataupun data terpilih.
#
# c) Circular Linked List merupakan suatu linked list dimana tail (node terakhir) menunjuk ke head (node pertama). Jadi tidak ada pointer yang menunjuk NULL.
# ![image.png](data:image/png;base64,...)
#
# d) **Single Linked List** adalah sebuah Linked List yang menggunakan sebuah variabel pointer saja untuk menyimpan banyak data dengan metode LL, suatu daftar isi yang saling berhubungan. sedangkan dalam **Double Linked List** memiliki 2 pointer yang dapat mengatasi kelemahan-kelemahan dari single Linked List tersebut. Dan **Circular Linked List** adalah double / single Linked List yang simpul terakhirnya menunjuk ke simpul awal, dan simpul awalnya menunjuk ke simpul akhir, atau dapat disebut Linked List yang dibuat seakan-akan merupakan sebuah lingkaran dengan titik awal dan titik akhir saling bersebelahan jika Linked List tersebut masih kosong.

# %% [markdown]
# # 3. Carilah deskripsi dan jelaskan salah satu contoh linear data structure yang lain, misalkan seperti Priority Queues / Maps / Hash Tables
#
#     JAWAB :
# - Priority Queues adalah struktur data Queue yang mana isi datanya terurut berdasarkan prioritasnya. Data dengan prioritas tertinggi akan dilayani terlebih dahulu dibandingkan dengan data dengan prioritas yang lebih rendah.
#
# - Maps adalah adalah metode terintegrasi yang memungkinkan semua objek diinterpretasikan dan diterjemahkan ke dalam iterable, bukan loop eksplisit, biasanya disebut sebagai pemetaan.
#
# - Hash Tables adalah sebuah struktur data yang terdiri atas sebuah tabel dan fungsi yang bertujuan untuk memetakan nilai kunci yang unik untuk setiap record menjadi angka (hash) lokasi record tersebut dalam sebuah tabel (singkatnya : penyimpanan data menggunakan key value yang didapat dari nilai data itu sendiri). Keunggulan dari struktur hash table ini adalah waktu aksesnya yang cukup cepat.
#
# contoh Hash Tables
#
# ![image.png](data:image/png;base64,...)
#
# Perhatikan range dari h untuk sembarang nilai k.
#
# Maka data 7 akan disimpan pada index 7, data 13 akan disimpan pada index 0, dst.
#
# Untuk mencari kembali suatu data, maka kita hanya perlu menggunakan hash function yang sama sehingga mendapatkan hash index yang sama pula.
#
# Misal : mencari data 25 → h = 25 (mod 13) = 12
#
# Namun pada penerapannya, seperti contoh di atas terdapat tabrakan (collision) pada k = 13 dan k = 39. Collision berarti ada lebih dari satu data yang memiliki hash index yang sama, padahal seperti yang kita ketahui, satu alamat / satu index array hanya dapat menyimpan satu data saja.

# %% [markdown]
# #4. Jelaskan kelebihan dan kekurangan dari Stacks, Queues , Deques, Single Linked List dan Double Linked List
#
#     JAWAB :
#
# 1.  **STACK**
#
#   |KELEBIHAN|
# - Membantu mengelola data dengan metode LIFO
# - Dapat membersihkan objek secara otomatis
# - Tidak mudah rusak
# - Mengontrol memori secara mandiri
#
#   |KEKURANGAN|
# - Stack memiliki memori yang sangat terbatas
# - Jika terlalu banyak objek, ada kemungkinan stack akan meluap atau overflow
# - Tidak memungkinkan akses acak, karena tumpukan paling atas harus dikeluarkan terlebih dahulu untuk mengakses tumpukan paling bawah
#
# ]
# 2.  **QUEUES**
#
#   |KELEBIHAN|
# - Data dalam jumlah besar dapat dikelola secara efisien.
# - Operasi seperti penyisipan dan penghapusan dapat dilakukan dengan mudah karena mengikuti aturan masuk pertama keluar pertama.
# - Queue berguna ketika layanan tertentu digunakan oleh banyak konsumen.
# - Queue cepat untuk komunikasi antar-proses data.
# - Queue dapat digunakan dalam implementasi struktur data lainnya
#
#   |KEKURANGAN|
# -  data yang terakhir masuk, bila waktu pelayanan habis kemungkinan bisa tidak dilayani
# -  Operasi seperti penyisipan dan penghapusan elemen dari tengah cenderung banyak memakan waktu.
# - elemen baru hanya dapat dimasukkan ketika elemen yang ada dihapus dari antrian.
#
# ]
#
# 3. **DEQUES**
#
#   |KELEBIHAN|
# - dapat digunakan untuk mengambil sebuah elemen dari queue. Hal ini dilakukan dengan cara memindahkan posisi head satu langkah ke belakang
#
#   |KEKURANGAN|
# - elemen baru hanya dapat dimasukkan ketika elemen yang ada dihapus dari antrian.
#
# ]
#
# 4. **SINGLE LINKED LIST**
#
#   |KELEBIHAN|
# - Lebih hemat space
# - Sederhana
#
#   |KEKURANGAN|
# - Pointernya hanya dapat bergerak ke satu arah saja (head -> tail)
# - Tidak dapt mengakses node sebelumnya dari node yang saat ini diakses
#
# ]
#
# 5. **DOUBLE LINKED LIST**
#
#   |KELEBIHAN|
# - Operasi REMOVE atau INSERT hanya dilakukan dengan
# mengubah pointer-nya saja
# - dapat menghapus dan menambah baik dari depan, belakang maupun tengah.
#
#   |KEKURANGAN|
# -  Diperlukan ruang tambahan untuk menyatakan/tempat field
# pointer
# - Diperlukan waktu yang lebih banyak untuk mencari suatu node
# dalam linked list
